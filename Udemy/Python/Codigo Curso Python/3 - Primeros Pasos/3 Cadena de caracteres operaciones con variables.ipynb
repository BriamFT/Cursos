# %%
print("""De esta manera
nos ahorramos a nuna
pero no a \tuna que es para la tabulación""")
# Out:
# De esta manera
# nos ahorramos a nuna
# pero no a 	una que es para la tabulación

# %%
variable = "Teoría sobre este tema donde salto de linea es con \n son dos líneas"

# %%
variable
# Out:
# 'Teoría sobre este tema donde salto de linea es con \n son dos líneas'

# %%
print(variable)
# Out:
# Teoría sobre este tema donde salto de linea es con
#  son dos líneas

# %%
variable + variable
# Out:
# 'Teoría sobre este tema donde salto de linea es con \n son dos líneasTeoría sobre este tema donde salto de linea es con \n son dos líneas'

# %%
variable
# Out:
# 'Teoría sobre este tema donde salto de linea es con \n son dos líneas'

# %%
print(variable + variable)
# Out:
# Teoría sobre este tema donde salto de linea es con
#  son dos líneasTeoría sobre este tema donde salto de linea es con
#  son dos líneas

# %%
primero = "primera parte"
segundo = " segunda parte"

# %%
print("Fusión de: " + primero + segundo)
# Out:
# Fusión de: primera parte segunda parte
