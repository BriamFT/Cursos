# %%
if True: 
    print("Imprimo esto porque la evaluación fue verdadera")

# %%
if True: 
print("Imprimo esto porque la evaluación fue verdadera")
# Out:
#   File "<ipython-input-1-1bc30e472a1a>", line 2
#     print("Imprimo esto porque la evaluación fue verdadera")
#     ^
# IndentationError: expected an indented block

# %%
if False: 
    print("Imprimo esto porque la evaluación fue verdadera")

# %%
variable = 10
if variable == 67:
    print("La variable vale: 67")
if variable == 10:
    print("La variable vale: 10")
# Out:
# La variable vale: 10
