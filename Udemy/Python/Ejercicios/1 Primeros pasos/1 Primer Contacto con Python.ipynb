# %%
5
# Out:
# 5

# %%
12.5
# Out:
# 12.5

# %%
5+4
# Out:
# 9

# %%
3*5
# Out:
# 15

# %%
3-2
# Out:
# 1

# %%
2-3
# Out:
# -1

# %%
5/8
# Out:
# 0.625

# %%
5%8
# Out:
# 5

# %%
2**8
# Out:
# 256

# %%
5+3*2*5-2/4
# Out:
# 34.5

# %%
#comentarios
variable = 5

# %%
variable
# Out:
# 5

# %%
variable+5
# Out:
# 10

# %%
variable = variable+5
