# %%
'Briam Flores'
# Out:
# 'Briam Flores'

# %%
stre = 'Briam Flores saluda a sus "Amigos"'

# %%
stre
# Out:
# 'Briam Flores saluda a sus "Amigos"'

# %%
'Briam saluda a sus "Amigos"'
# Out:
# 'Briam saluda a sus "Amigos"'

# %%
"hola 'Briam'"
# Out:
# "hola 'Briam'"

# %%
print('Comillas simples')
# Out:
# Comillas simples

# %%
print("Comillas dobles")
# Out:
# Comillas dobles

# %%
print('Flores "hola"')
# Out:
# Flores "hola"

# %%
print(" este texto tiene \n una nueva linea")
# Out:
#  este texto tiene
#  una nueva linea

# %%
print("Este texto tiene \nuna nueva linea")
# Out:
# Este texto tiene
# una nueva linea

# %%
print(" este texto tiene \tuna tabulación")
# Out:
#  este texto tiene 	una tabulación

# %%
print('C:\nombres\clases')
# Out:
# C:
# ombres\clases

# %%
print(r'C:\nombres\clases')
# Out:
# C:\nombres\clases
