# %%
input()
# Out:
# Briam
# 'Briam'

# %%
'Briam'
# Out:
# 'Briam'

# %%
dato = input()
# Out:
# Briam Flores

# %%
dato
# Out:
# 'Briam Flores'

# %%
dato_num = input()
# Out:
# 7

# %%
dato_num
# Out:
# '7'

# %%
dato_num + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-26f98a169344> in <module>
# ----> 1 dato_num + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
dato_num = int(dato_num)
dato_num
# Out:
# 7

# %%
dato_num + 3
# Out:
# 10

# %%
dato_float = input()
# Out:
# 5.5

# %%
dato_float
# Out:
# '5.5'

# %%
dato_float = float(dato_float)
dato_float
# Out:
# 5.5

# %%
dato_float + 4.5
# Out:
# 10.0

# %%
dato_final = float(input("Introduce un valor decimal: "))
# Out:
# Introduce un valor decimal: 3.1416

# %%
dato_final
# Out:
# 3.1416
