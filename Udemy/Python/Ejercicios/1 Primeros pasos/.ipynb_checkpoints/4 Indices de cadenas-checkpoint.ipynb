# %%
profesor = "Briam Flores"

# %%
profesor[2]
# Out:
# 'i'

# %%
profesor[6]
# Out:
# 'F'

# %%
profesor[5]
# Out:
# ' '

# %%
profesor[-1]
# Out:
# 's'

# %%
profesor[-6]
# Out:
# 'F'

# %%
profesor[0:5]
# Out:
# 'Briam'

# %%
profesor[:5]
# Out:
# 'Briam'

# %%
profesor[6:]
# Out:
# 'Flores'

# %%
len(profesor)
# Out:
# 12
