# %%
# Verdadero / Falso

# %%
2 + 4 == 7
# Out:
# False

# %%
2 + 3 == 5
# Out:
# True

# %%
# Operadores lógicos
# NOT - AND - OR

# %%
not True
# Out:
# False

# %%
not False == True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
numero = 10
numero > 9 and numero < 12
# Out:
# True

# %%
numero > 5 and numero > 12
# Out:
# False

# %%
True and False
# Out:
# False

# %%
numero > 5 or numero > 12
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
palabra = "Briam"

# %%
palabra == "Salir" or palabra == "Terminar" or palabra == "Exit"
# Out:
# False

# %%
 palabra[0] == "F"
# Out:
# False

# %%
palabra[0] == "b"
# Out:
# False
