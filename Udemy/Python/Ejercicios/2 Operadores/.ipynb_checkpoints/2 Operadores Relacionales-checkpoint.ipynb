# %%
#Operadores relacionales
# != , == , >, < , >= , <=

# %%
1 != 0
# Out:
# True

# %%
4 > 10
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
3 < 10
# Out:
# True

# %%
10 >= 10
# Out:
# True

# %%
9 >= 10
# Out:
# False

# %%
n = 10
a = 5
b = 0

# %%
n > a
# Out:
# True

# %%
n != b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a == b+5
# Out:
# True

# %%
"Briam" == "Briam"
# Out:
# True

# %%
"briam" == "Briam"
# Out:
# False

# %%
"briam" != "Briam"
# Out:
# True

# %%
texto = "Flores"

# %%
texto[0] == "F"
# Out:
# True

# %%
lista1 = [1,2,3]
lista2 = {4,5,6}

# %%
lista1 == lista2
# Out:
# False

# %%
len(lista1) == len(lista2)
# Out:
# True

# %%
True ==1
# Out:
# True

# %%
False == 0
# Out:
# True
